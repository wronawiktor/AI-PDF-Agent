# %%
"""
 Copyright 2024 Adobe
 All Rights Reserved.

 NOTICE: Adobe permits you to use, modify, and distribute this file in
 accordance with the terms of the Adobe license agreement accompanying it.
"""

import logging
import os
from datetime import datetime

from adobe.pdfservices.operation.auth.service_principal_credentials import ServicePrincipalCredentials
from adobe.pdfservices.operation.exception.exceptions import ServiceApiException, ServiceUsageException, SdkException
from adobe.pdfservices.operation.pdf_services_media_type import PDFServicesMediaType
from adobe.pdfservices.operation.io.cloud_asset import CloudAsset
from adobe.pdfservices.operation.io.stream_asset import StreamAsset
from adobe.pdfservices.operation.pdf_services import PDFServices
from adobe.pdfservices.operation.pdfjobs.jobs.extract_pdf_job import ExtractPDFJob
from adobe.pdfservices.operation.pdfjobs.params.extract_pdf.extract_element_type import ExtractElementType
from adobe.pdfservices.operation.pdfjobs.params.extract_pdf.extract_pdf_params import ExtractPDFParams
from adobe.pdfservices.operation.pdfjobs.result.extract_pdf_result import ExtractPDFResult

# Initialize the logger
logging.basicConfig(level=logging.INFO)

from dotenv import load_dotenv
load_dotenv()
import os

# Access environment variables
client_id = os.getenv("ADOBE-client-id")
client_secret = os.getenv("ADOBE-client-secret")

# %%
file = open('extractPdfInput.pdf', 'rb')
input_stream = file.read()
file.close()

# Initial setup, create credentials instance
credentials = ServicePrincipalCredentials(
    client_id=client_id,
    client_secret=client_secret
)

# Creates a PDF Services instance
pdf_services = PDFServices(credentials=credentials)

# Creates an asset(s) from source file(s) and upload
input_asset = pdf_services.upload(input_stream=input_stream, mime_type=PDFServicesMediaType.PDF)

# Create parameters for the job
extract_pdf_params = ExtractPDFParams(
    elements_to_extract=[ExtractElementType.TEXT],
)

# Creates a new job instance
extract_pdf_job = ExtractPDFJob(input_asset=input_asset, extract_pdf_params=extract_pdf_params)

# Submit the job and gets the job result
location = pdf_services.submit(extract_pdf_job)
pdf_services_response = pdf_services.get_job_result(location, ExtractPDFResult)

# Get content from the resulting asset(s)
result_asset: CloudAsset = pdf_services_response.get_result().get_resource()
stream_asset: StreamAsset = pdf_services.get_content(result_asset)
# Out:
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started uploading asset
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished uploading asset
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started submitting EXTRACT_PDF job
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started getting job result
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished polling for status
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished getting job result
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Started getting content
# INFO:adobe.pdfservices.operation.internal.pdf_services_helper:Finished getting content

# %%
print("Extracted text: ")
print(stream_asset.get_input_stream())
# Out:
# Extracted text:
# b'PK\x03\x04\x14\x00\x00\x00\x08\x00\x16w\x14Y\x9f\xbbA\x11\xd4)\x00\x00\x11.\x01\x00\x13\x00\x00\x00structuredData.json\xed}[s\xdb\xc6\xb6\xe6_A\xf9\xc9\xaeQ\xe0\xbe_\xf6<\xf9\x92\x1c\xfb\x8cw\xa2\xb1\x9d\x9d]\xc9\xa4\\\x10\xd9\x12\xb1\r\x02<\x00hY\x93\xda\xff}\xd6\xea\x06H\x90\x84$\x10\xa23G\x15\xf8A\x96pm\xf4\xb7\xeek\xf5\xea?\x9e|qe\x95\x16\xf9\x93\xbfE\x7f<\xf9WU\xe4\x9f\xdc\xd7UQ\xd6\xf0\xf7\x13F\xf8\x93\xb3\xe8\xc9*\xb9r\x9f*w\xb5ty\x9d\xd4\xe1\xda\'\x12\xcfT\xb3\x85[&\xf8\'\x8diL\xfc\xa1\xba\\\xcf\xeau\xe9\x9a\xa3\xc4\xdap\xa2N.2xL\xf7\xb4|\xf2o8\xe1\xbe\xd6.\x9f\xbb\xf9\xa7\xa5\xab\x93yR\'~(o_\x7fJ\xf3\xaaN\xf2\x99\xbf\xf4\x15\x89^\x8b\xc8\xd8\xe8\x07\x12\xbd\xa0\xd1\xcb\x17\xd1K\x16Q\x1a\x91\x17\x11!\x91\xd2\x91\x90\x91y\x19\xa9\x97\xd1+\x151\x1e\xe1\x1b\xe1\x11+W.\x93\x1c\xc6\x8d\xcf\xe0"\x12p\x92\xe0\xb5\xe1\x17n".\xfd\x11\x15q\xe2\x7f\xa1\x11\xa7\xfe\x17\x86\xbf\x87_8\xf3\x17\xb7\xa78iNq\xd2\xdc\xc5\xe1v\xed\x7f\x11\xcd\x03\xe1\xc9\x825\xa7\xc2/\x82\xe3\xefx\x04\x1e\xc8\xf1\x17\x1c\xe3"\xa9>%\xb3\xb2\xb8,\xca%\x8c\xf12\xc9*\xd7\x1cv\xcb\x0b7\xc7y\xb9L3WuN\xa6\xd5\xa7\x7f\xfe\xf0b\xf7\xc0\xcc\x95uz\x99\xba\xf9\xeea\x97\xcf\xca\x9bU\xbd\x7fx\x9e^\xa5u\x92e7\x9f\xaa\xf4*\xdf9\x9b%\xf9\xd5\x1a\x00\xc7\t\xfb\xfe\xc7\xef~\xfe\xb0\xa1\x80Y\xb1\xf6\xf3\xc8\xf1\xc0\xfc\xf2\xd3\x96p\x00g\xf5$\x1cM\xe0\xb2\xe5*K\x11\xb7O\x99\xfb\xe22<\xdf\x9c\\\xdfr\xd6SA\xe6\x90\xbe\xf0;\x7f\xfb\xe3\xc9Kx\xd7\xdc\xff.Dl\x0c!D\x18\xc3\x0ce\xf2,\xd2R\xc7\xc42+\x95\x14\xcc*c\xce"\x06WY\xa2$\xb1\xdcZA\x05Qp\x99\xd2\xb1\xd4L\xc2?A\xade\xecwx\xcb\x0f\x85\xff\x84?\x9e$Y\xfd\xe92Y\xa60\x05y\xb2\x0c$\x96\xb9$\xc7\x91\xb6\x13\x0f\x07\x81ZqR`\x1a\x8by\x9a_\xe1e\xbf\xa4\xf9\x8b\xbcJ\xbfo\x0f\xc1\xe9\xbd\x07\xbd\x98\x17\x17.\xda<\xee\x12\xde\xf9\xa9\xbeY\xf9s\x1f\xe1\x7f\x8aGq\xfe\xd3Yg\xe2\x97E^T\xabd\xb6\x83F\xfb\xc8\x9f\xff\xf1\x9f\xef~\xf8\xfe\x7f\xf8\'\xfb\x07\x7f\xf7\xde]\xad\xb3\xa4\xf4,\xb7\xbe\xa8\\\xbd\x1d\xed\xb5K\xaf\x16\xf8\xb7 \x04\xa7\xf6MR\xbd\xca\xd2U\xe7\xb1\xef\x92\xf0-\xce\x0f\xf0\xa7\x8b\x7f\xb9Y\xfd\xf65\x1cQ\xcc\xc2\x81\xf3\x80?\xf1\xbf\xd6\x0b\xbc\xf2\xf9\xf3\xd7\xc5l\x8d\x08=\xff\x00\x17??\xc7\x1b?\x02\xebn?\xf8\x1f\xc0\xc5E\x19\xc1\xe9u\x99\xd67\xd1{\xf7%u\xd7\xd1yY\\\x95\xc92\xfae\x91\xd6.:O\x80%\xa3\xf6\xe6\x0f\xe9\xff\xc5\x17\x99X2\x84\x98i&\x14`\x08\x88>I\xea\xbaL/\xd6\xb5\xa7\xfc?\x9e|\xc0\x99yqY\xbb\x12\xfe\xa4\xe6\xdf\xf0]]*\x91\xc2\xc6TX\x0b\xf7Z%\x8c\x10\x80\xbf 1W\xdc*m\xac\x94D\xc3C\xa5\x91\xb1\x82\x17\x11E\t\x97T"\x95X\x12\x13\t\x878\x91\x14(\xcb\xfc\xbe7!\x9c\x0c\x9b\x90\x1f\xd2+\x94j\x87#\x7f\xf9\xb2\xf8\xda\x0e\x91Qm\x9b\x7f\\\x86!\n\xc2\xdaC\x94\x85!\n)\x9b#Z\xe1U\xc6\xc6F\x90\xe6\x90\x91~\x88\xe7\x19\xcc\xc7\xb2\x11l/\xb3b\xf6\xf9\xc9\xfe\x9cP#b\x01$@\x80;\x90%\x90w\x14W15\xca*i\x05\xe3\xc0Q\xf0FJ@J\x0b.\x05<\x9a[?wp:\x96\x86Ji\x18\xd3\x92[:\xf1\xce\x00\xde\xe1t\x18\xa9|L\xeb\xcc\x1d\xf0\xcf\xffY\x13\x92\xdc\xcbE{\x9cCA\xb9\xde\xc7:\xef\xd2\xdc\xbdi?\x8b\xb1\xd8h \x84=\x86\x121\x93\x83\xe8\x87\x98XiI8\x97\xca\xc2\x0f\x90\x16\x8c\xdb\x18^\xcd\x05\x13D3\xa6\x90\xab\x14\x130.)\xb8\x12\x84r\xa5\'\xd9;\x88~\xd8 \xfa\xf9\x8d\xfd\xfe\xfc\r\xed\xd2\xcfO\xa0\x8a=\x95\xecS\x07\x8b\x05\n\x1cP\x83\xc8\xc5\x00\xe1=\xd4A\x0f\x88@\x808\xa2(v\xa82VH$qa\xc1\xd4\xa3\xcch#@\x9c)ON\x94hP\xc0\\hfA\x94\x867\x81T\x05\xb9\x15\xc4\x0c(\xee\xc7L\x02\xbf\xfe\xf2\xee\xc5?\x7f\xee\x92\xc0\xcb"\x9b\xdf\x89\xbf\x1e\x81?\x1f\x8c\xff\x8b*\x9d\xbb]%\xfc\x11\xed\xeb\xa8\xb8\x8c^\xc1\x07\xa3%\xb5O\r\x80\xd0.1\xc8C\xac9\xe9\xa8B\xc4Z\xdb\xd8re(\xf0\xba\x10`D!\xac\xb1\xb1\\\x9bV\x02\x80\xba\x10\xa0\xa1$\xb0\xb94\x821\x83\x8a\xf51\x83\xfd\xf3\xaf\xbf\xbc\xdf\xe5\xf7\x0fn\x99\xbe\xca\xc7\xb1\xfb\x0e\xc0\xe2H\x80\xdf=\x7f\xf7\xf6\xf9\xbb\x8b\xac\x8b3=\x1aWI\x87\xe0\n\x86\x10\xe8\x10\xb0F\xc0\\&\x00!\x9bp\x1d\x8c\xab\x1c\x85\xeb\xcbb~3D\x8c\x0fa\\\x86\x8a\x1aLLN\x95\xf7~\x842\xc0\xa6\xca\x80q\xa0L\xe0R`\\4}5\xe5\x06~x\xb1-\xb4\x89\x05X\xc8J\xa2\x96\xc6c\x13\xc0\xbd\x00\xab\x11\x00\xe3_\x0f\xe7]4\xce;\x1e\x0b\x1aa=\xd8R\xceb\xb9\x81\x9fM\xd0\x0e\x87V\x8 ...

# %%
import zipfile
import io
import json

# Assuming stream_asset.get_input_stream() returns a file-like object
input_stream = stream_asset.get_input_stream()

# Create a BytesIO object from the input stream
bytes_io = io.BytesIO(input_stream)

# Open the zip file
with zipfile.ZipFile(bytes_io, 'r') as zip_ref:
    # List all files in the zip archive
    with zip_ref.open('structuredData.json') as f:
        content = f.read()
        print(content.decode('utf-8'))  # Assuming the file is text; decode accordingly
        parsed = json.loads(content.decode('utf-8'))
        print(json.dumps(parsed, indent=4))  # Assuming the file is JSON; decode accordingly
# Out:
# {"version": {"json_export": "203", "page_segmentation": "5", "schema": "1.1.0", "structure": "1.1099.0", "table_structure": "5"}, "extended_metadata": {"ID_instance": "C0 D4 89 F0 A1 BA B2 11 0A 00 67 45 8B 6B C6 23 ", "ID_permanent": "34 46 20 45 46 20 38 35 20 46 30 20 41 31 20 42 41 20 42 32 20 31 31 20 30 41 20 30 30 20 36 37 20 34 35 20 38 42 20 36 42 20 43 36 20 32 33 20 ", "has_acroform": false, "has_embedded_files": false, "is_XFA": false, "is_certified": false, "is_encrypted": false, "is_digitally_signed": false, "language": "EN-US", "page_count": 3, "pdf_version": "1.6", "pdfa_compliance_level": "", "pdfua_compliance_level": ""}, "elements": [{"Bounds": [44.8800048828125, 757.0929565429688, 244.90650939941406, 767.5725555419922], "Font": {"alt_family_name": "Clean", "embedded": true, "encoding": "WinAnsiEncoding", "family_name": "Adobe Clean", "font_type": "Type1", "italic": false, "monospaced": false, "name": "UVJLFE+AdobeClean-Regular", "subset": true, "weight": 400}, "HasClip": false, "Lang": "en", "ObjectID": 629, "Page": 0, "Path": "//Document/Sect/P", "Text": "Adobe Vendor Security Review Program White Paper ", "TextSize": 8.520004272460938, "attributes": {"SpaceAfter": 18}}, {"Bounds": [549.1499938964844, 740.3639678955078, 585.6000061035156, 790.0500030517578], "ObjectID": 630, "Page": 0, "Path": "//Document/Sect/Figure", "attributes": {"BBox": [549.2179999999935, 740.4029999999912, 585.4559999999765, 789.8409999999858], "Placement": "Block"}}, {"Bounds": [184.44000244140625, 636.1869659423828, 510.10435485839844, 659.5815582275391], "Font": {"alt_family_name": "Clean", "embedded": true, "encoding": "WinAnsiEncoding", "family_name": "Adobe Clean", "font_type": "Type1", "italic": false, "monospaced": false, "name": "UVJLFE+AdobeClean-Regular", "subset": true, "weight": 400}, "HasClip": false, "Lang": "en", "ObjectID": 631, "Page": 0, "Path": "//Document/Sect/Title", "Text": "Adobe\u00ae Vendor Security Review Program ", "TextSize": 19.020004272460938, "attributes": {"LineHeight": 22.875, "SpaceAfter": 14.25}}, {"Bounds": [184.44000244140625, 608.6750335693359, 239.46034240722656, 624.0254364013672], "Font": {"alt_family_name": "Clean", "embedded": true, "encoding": "WinAnsiEncoding", "family_name": "Adobe Clean", "font_type": "Type1", "italic": false, "monospaced": false, "name": "UVJLFE+AdobeClean-Regular", "subset": true, "weight": 400}, "HasClip": false, "Lang": "en", "ObjectID": 632, "Page": 0, "Path": "//Document/Sect[2]/H1", "Text": "Overview ", "TextSize": 12.479995727539062, "attributes": {"LineHeight": 15}}, {"Bounds": [45.41999816894531, 491.01287841796875, 107.90347290039062, 500.84423828125], "Font": {"alt_family_name": "Clean", "embedded": true, "encoding": "WinAnsiEncoding", "family_name": "Adobe Clean", "font_type": "Type1", "italic": false, "monospaced": false, "name": "ZWLAXU+AdobeClean-Bold", "subset": true, "weight": 700}, "HasClip": false, "Lang": "en", "ObjectID": 633, "Page": 0, "Path": "//Document/Sect[2]/Aside/P", "Text": "Table of Contents ", "TextSize": 7.9799957275390625}, {"Bounds": [45.30000305175781, 479.9368133544922, 50.89378356933594, 489.53675842285156], "Font": {"alt_family_name": "Clean", "embedded": true, "encoding": "WinAnsiEncoding", "family_name": "Adobe Clean", "font_type": "Type1", "italic": false, "monospaced": false, "name": "UZWRFE+AdobeClean-SemiCn", "subset": true, "weight": 400}, "HasClip": false, "ObjectID": 634, "Page": 0, "Path": "//Document/Sect[2]/Aside/L/LI/Lbl", "Text": "1 ", "TextSize": 7.9799957275390625}, {"Bounds": [51.30000305175781, 479.9368133544922, 90.72402954101562, 489.53675842285156], "Font": {"alt_family_name": "Clean", "embedded": true, "encoding": "WinAnsiEncoding", "family_name": "Adobe Clean", "font_type": "Type1", "italic": false, "monospaced": false, "name": "UZWRFE+AdobeClean-SemiCn", "subset": true, "weight": 400}, "HasClip": false, "ObjectID": 635, "Page": 0, "Path": "//Document/Sect[2]/Aside/L/LI/LBody", "Text": "Overview ", "TextSiz ...
# {
#     "version": {
#         "json_export": "203",
#         "page_segmentation": "5",
#         "schema": "1.1.0",
#         "structure": "1.1099.0",
#         "table_structure": "5"
#     },
#     "extended_metadata": {
#         "ID_instance": "C0 D4 89 F0 A1 BA B2 11 0A 00 67 45 8B 6B C6 23 ",
#         "ID_permanent": "34 46 20 45 46 20 38 35 20 46 30 20 41 31 20 42 41 20 42 32 20 31 31 20 30 41 20 30 30 20 36 37 20 34 35 20 38 42 20 36 42 20 43 36 20 32 33 20 ",
#         "has_acroform": false,
#         "has_embedded_files": false,
#         "is_XFA": false,
#         "is_certified": false,
#         "is_encrypted": false,
#         "is_digitally_signed": false,
#         "language": "EN-US",
#         "page_count": 3,
#         "pdf_version": "1.6",
#         "pdfa_compliance_level": "",
#         "pdfua_compliance_level": ""
#     },
#     "elements": [
#         {
#             "Bounds": [
#                 44.8800048828125,
#                 757.0929565429688,
#                 244.90650939941406,
#                 767.5725555419922
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 629,
#             "Page": 0,
#             "Path": "//Document/Sect/P",
#             "Text": "Adobe Vendor Security Review Program White Paper ",
#             "TextSize": 8.520004272460938,
#             "attributes": {
#                 "SpaceAfter": 18
#             }
#         },
#         {
#             "Bounds": [
#                 549.1499938964844,
#                 740.3639678955078,
#                 585.6000061035156,
#                 790.0500030517578
#             ],
#             "ObjectID": 630,
#             "Page": 0,
#             "Path": "//Document/Sect/Figure",
#             "attributes": {
#                 "BBox": [
#                     549.2179999999935,
#                     740.4029999999912,
#                     585.4559999999765,
#                     789.8409999999858
#                 ],
#                 "Placement": "Block"
#             }
#         },
#         {
#             "Bounds": [
#                 184.44000244140625,
#                 636.1869659423828,
#                 510.10435485839844,
#                 659.5815582275391
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 631,
#             "Page": 0,
#             "Path": "//Document/Sect/Title",
#             "Text": "Adobe\u00ae Vendor Security Review Program ",
#             "TextSize": 19.020004272460938,
#             "attributes": {
#                 "LineHeight": 22.875,
#                 "SpaceAfter": 14.25
#             }
#         },
#         {
#             "Bounds": [
#                 184.44000244140625,
#                 608.6750335693359,
#                 239.46034240722656,
#                 624.0254364013672
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 632,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/H1",
#             "Text": "Overview ",
#             "TextSize": 12.479995727539062,
#             "attributes": {
#                 "LineHeight": 15
#             }
#         },
#         {
#             "Bounds": [
#                 45.41999816894531,
#                 491.01287841796875,
#                 107.90347290039062,
#                 500.84423828125
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "ZWLAXU+AdobeClean-Bold",
#                 "subset": true,
#                 "weight": 700
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 633,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/P",
#             "Text": "Table of Contents ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 45.30000305175781,
#                 479.9368133544922,
#                 50.89378356933594,
#                 489.53675842285156
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 634,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI/Lbl",
#             "Text": "1 ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 51.30000305175781,
#                 479.9368133544922,
#                 90.72402954101562,
#                 489.53675842285156
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 635,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI/LBody",
#             "Text": "Overview ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 45.24000549316406,
#                 468.8968200683594,
#                 50.00067138671875,
#                 478.49676513671875
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 636,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI[2]/Lbl",
#             "Text": "1 ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 50.100006103515625,
#                 468.8968200683594,
#                 132.554931640625,
#                 478.49676513671875
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 637,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI[2]/LBody/ParagraphSpan",
#             "Text": "Adobe Vendor Security ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 56.94000244140625,
#                 459.29681396484375,
#                 131.1805877685547,
#                 468.8967590332031
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 638,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI[2]/LBody/L/LI/LBody",
#             "Text": "Review (VSR) Process ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 45.30000305175781,
#                 448.25682067871094,
#                 49.88214111328125,
#                 457.8567657470703
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 639,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI[3]/Lbl",
#             "Text": "1 ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 51.242706298828125,
#                 448.25682067871094,
#                 115.85755920410156,
#                 457.8567657470703
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 640,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI[3]/LBody",
#             "Text": "Data Classification ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 45.30000305175781,
#                 437.2168273925781,
#                 51.32511901855469,
#                 446.81675720214844
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 641,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI[4]/Lbl",
#             "Text": "4 ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 56.343292236328125,
#                 437.2168273925781,
#                 130.33421325683594,
#                 446.81675720214844
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 642,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI[4]/LBody",
#             "Text": "VSR Security Controls ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 45.65785217285156,
#                 426.11663818359375,
#                 51.633056640625,
#                 435.7165832519531
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 643,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI[5]/Lbl",
#             "Text": "5 ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 56.40155029296875,
#                 406.9168243408203,
#                 122.65103149414062,
#                 435.7165832519531
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 644,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI[5]/LBody",
#             "Text": "The Adobe Vendor Information Security Standard ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 45.660003662109375,
#                 395.87681579589844,
#                 51.96263122558594,
#                 405.4767608642578
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 645,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI[6]/Lbl",
#             "Text": "5 ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 56.339996337890625,
#                 395.87681579589844,
#                 126.56942749023438,
#                 405.4767608642578
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 646,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI[6]/LBody",
#             "Text": "Vendor Engagement ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 45.47999572753906,
#                 384.8368225097656,
#                 52.18646240234375,
#                 394.436767578125
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 647,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI[7]/Lbl",
#             "Text": "6 ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 56.339996337890625,
#                 384.8368225097656,
#                 122.5997314453125,
#                 394.436767578125
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 648,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI[7]/LBody",
#             "Text": "Privacy Assessment ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 45.476593017578125,
#                 373.80052185058594,
#                 51.57337951660156,
#                 383.4004669189453
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 649,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI[8]/Lbl",
#             "Text": "6 ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 56.399993896484375,
#                 373.79681396484375,
#                 115.90223693847656,
#                 383.3967590332031
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 650,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI[8]/LBody",
#             "Text": "Legal Obligations ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 45.12080383300781,
#                 362.76051330566406,
#                 50.58708190917969,
#                 372.36045837402344
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 651,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI[9]/Lbl",
#             "Text": "7 ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 56.399993896484375,
#                 362.75682067871094,
#                 95.01419067382812,
#                 372.3567657470703
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 652,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/Aside/L/LI[9]/LBody",
#             "Text": "Conclusion ",
#             "TextSize": 7.9799957275390625
#         },
#         {
#             "Bounds": [
#                 184.39283752441406,
#                 543.4259948730469,
#                 572.1136016845703,
#                 603.5820007324219
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 653,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/P",
#             "Text": "Managed by the Adobe Information Security team, Adobe\u2019s vendor security review (VSR) program includes a set of requirements to which third-party vendors that collect, store, process, transmit, or dispose of Adobe Internal, Confidential, or Restricted data outside of Adobe-controlled physical offices or data center locations must adhere. Typical scenarios include vendors processing and storing Adobe data at their site, cloud services (e.g., SaaS, PaaS, IaaS, and XaaS), and data centers. ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 184.4022674560547,
#                 488.65199279785156,
#                 582.5422210693359,
#                 536.5050048828125
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 654,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/P[2]",
#             "Text": "The Adobe VSR program evaluates each vendor\u2019s compliance to Adobe\u2019s Vendor Information Security Standard, providing a risk-based review of the vendor\u2019s security practices and enabling Adobe managers to make fact-based decisions concerning whether or not to enter into a relationship with that vendor. ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 184.39283752441406,
#                 397.03199768066406,
#                 578.6869964599609,
#                 481.6679992675781
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 655,
#             "Page": 0,
#             "Path": "//Document/Sect[2]/P[3]",
#             "Text": "The management of vendor relationships and their interactions with Adobe information and technologyresources is an essential element of information security. The VSR program is a logical extension of Adobe\u2019s belief that every action taken on or interaction with data should be conducted with a lens of security to help ensure the security, privacy, and availability of our customers\u2019 and employees\u2019 data, no matter where it is stored or processed, which is one of the key controls within the Adobe Common Controls Framework (CCF). With the VSR program, Adobe helps ensure that its culture of security extends to any vendor with whom the company does business. ",
#             "TextSize": 9.0,
#             "attributes": {
#                 "SpaceAfter": 13.375
#             }
#         },
#         {
#             "Bounds": [
#                 184.44000244140625,
#                 367.89503479003906,
#                 484.02496337890625,
#                 383.2454376220703
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 657,
#             "Page": 0,
#             "Path": "//Document/Sect[3]/H1",
#             "Text": "Adobe Vendor Security Review (VSR) Program Process ",
#             "TextSize": 12.479995727539062,
#             "attributes": {
#                 "LineHeight": 15
#             }
#         },
#         {
#             "Bounds": [
#                 184.43057250976562,
#                 339.4290008544922,
#                 574.5328369140625,
#                 362.802001953125
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 658,
#             "Page": 0,
#             "Path": "//Document/Sect[3]/P",
#             "Text": "The VSR program evaluates a third-party vendor\u2019s compliance with the Adobe Vendor Information Security Standard (described above). ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 184.4116973876953,
#                 284.58299255371094,
#                 568.0270538330078,
#                 332.4989929199219
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 659,
#             "Page": 0,
#             "Path": "//Document/Sect[3]/P[2]",
#             "Text": "Business owners within Adobe that wish to enter into a relationship with a third-party vendor initiatethe process with a VSR request, which includes a description of the service provided by the vendor, whether the vendor will process Adobe data off-site, and the classification of the data the vendor intends to process. ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 184.43057250976562,
#                 242.10299682617188,
#                 550.4246520996094,
#                 277.71600341796875
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 660,
#             "Page": 0,
#             "Path": "//Document/Sect[3]/P[3]",
#             "Text": "Based on the information provided by the business owner, Adobe sends the main point of contactat the vendor a detailed questionnaire, including questions from each security control area (see VSR Security Controls section). ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 184.39283752441406,
#                 138.18299865722656,
#                 582.8440856933594,
#                 235.1219940185547
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 662,
#             "Page": 0,
#             "Path": "//Document/Sect[3]/P[4]",
#             "Text": "After the vendor completes and returns the questionnaire, Adobe information security analysts review the information and perform a gap assessment. A vendor is assigned a risk level score of \u201ccritical,\u201d \u201chigh,\u201d \u201cmedium,\u201d or \u201clow\u201d based upon a risk matrix used by our risk analysts. If Adobe finds any gaps in, or deviations from, Adobe security standards, a risk analyst holds discussions with the business owner to understand the details about the gap and to provide potential remediation suggestions. The analyst documents the recommended remediation and the actions to be performed by the vendor and/or the business owner. If necessary, risk analysts will meet directly with vendors to resolve more complex issues. ",
#             "TextSize": 9.0,
#             "attributes": {
#                 "SpaceAfter": 13.25
#             }
#         },
#         {
#             "Bounds": [
#                 184.44000244140625,
#                 109.05503845214844,
#                 286.38099670410156,
#                 124.40544128417969
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 442,
#             "Page": 0,
#             "Path": "//Document/Sect[4]/H1",
#             "Text": "Data Classification ",
#             "TextSize": 12.479995727539062,
#             "attributes": {
#                 "LineHeight": 15
#             }
#         },
#         {
#             "Bounds": [
#                 184.43057250976562,
#                 31.626007080078125,
#                 579.2398071289062,
#                 104.02200317382812
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 443,
#             "Page": 0,
#             "Path": "//Document/Sect[4]/P",
#             "Text": "Adobe developed the Adobe Data Classification and Handling Standard to aid in ensuring the security and privacy of all data that Adobe collects, processes, stores, uses, or otherwise handles regardless of whether the data is owned by Adobe or a third party, where the data is located (e.g., Adobe data center,colocation), or the type of hardware or media on which the data resides, whether paper or electronic (e.g., server, desktop, laptop, mobile device, USB flash drive). The standard establishes that all data ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 184.47169494628906,
#                 719.8289947509766,
#                 535.8946685791016,
#                 767.6820068359375
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 444,
#             "Page": 1,
#             "Path": "//Document/Sect[4]/P[2]",
#             "Text": "collected, processed, transmitted, stored, or destroyed by or on behalf of Adobe must be classified and then protected in accordance with its designated classification. The specific classifications in the standard define with whom employees can share Adobe data and determine where and how toshare, protect, and secure this data. ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 184.4969940185547,
#                 701.8320007324219,
#                 515.9400177001953,
#                 712.9019927978516
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 445,
#             "Page": 1,
#             "Path": "//Document/Sect[4]/P[3]",
#             "Text": "The Adobe Data Classification and Handling Standard includes four (4) classifications: ",
#             "TextSize": 9.0,
#             "attributes": {
#                 "SpaceAfter": 4.5
#             }
#         },
#         {
#             "Bounds": [
#                 184.41600036621094,
#                 686.6490020751953,
#                 189.4559783935547,
#                 697.718994140625
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 600,
#             "Page": 1,
#             "Path": "//Document/Sect[4]/L/LI/Lbl",
#             "Text": "\u2022 ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 191.52000427246094,
#                 686.6519927978516,
#                 261.9802703857422,
#                 697.7220001220703
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 601,
#             "Page": 1,
#             "Path": "//Document/Sect[4]/L/LI/LBody",
#             "Text": "Adobe Restricted ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 184.44000244140625,
#                 668.5890045166016,
#                 189.47998046875,
#                 679.6589965820312
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 598,
#             "Page": 1,
#             "Path": "//Document/Sect[4]/L/LI[2]/Lbl",
#             "Text": "\u2022 ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 191.52000427246094,
#                 668.5919952392578,
#                 270.3101806640625,
#                 679.6620025634766
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 599,
#             "Page": 1,
#             "Path": "//Document/Sect[4]/L/LI[2]/LBody",
#             "Text": "Adobe Confidential ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 184.44000244140625,
#                 650.5290069580078,
#                 189.47998046875,
#                 661.5989990234375
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 596,
#             "Page": 1,
#             "Path": "//Document/Sect[4]/L/LI[3]/Lbl",
#             "Text": "\u2022 ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 191.52000427246094,
#                 650.5319976806641,
#                 252.88612365722656,
#                 661.6020050048828
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 597,
#             "Page": 1,
#             "Path": "//Document/Sect[4]/L/LI[3]/LBody",
#             "Text": "Adobe Internal ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 184.43699645996094,
#                 632.468994140625,
#                 189.4769744873047,
#                 643.5390014648438
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 594,
#             "Page": 1,
#             "Path": "//Document/Sect[4]/L/LI[4]/Lbl",
#             "Text": "\u2022 ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 191.52000427246094,
#                 632.4720001220703,
#                 218.01950073242188,
#                 643.5420074462891
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 595,
#             "Page": 1,
#             "Path": "//Document/Sect[4]/L/LI[4]/LBody",
#             "Text": "Public ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 184.46359252929688,
#                 574.8719940185547,
#                 543.821533203125,
#                 622.7250061035156
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 447,
#             "Page": 1,
#             "Path": "//Document/Sect[4]/P[4]",
#             "Text": "A VSR is required for all third-party vendors that store or process data classified as Adobe Restricted, Confidential, or Internal off-premise (not at Adobe). Depending on the classification of the data handled by the vendor, a new VSR is required either annually or biannually (see Recertification section). ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 184.46226501464844,
#                 532.2689971923828,
#                 546.6343383789062,
#                 567.8820037841797
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
# ...
#                 "weight": 400
#             },
#             "HasClip": true,
#             "Lang": "en",
#             "ObjectID": 419,
#             "Page": 2,
#             "Path": "//Document/Sect[4]/Sect/Table/TR[4]/TD[2]/P",
#             "Text": "May cause minor embarrassment or operational inconvenience ",
#             "TextSize": 7.9799957275390625,
#             "attributes": {
#                 "LineHeight": 10
#             }
#         },
#         {
#             "Bounds": [
#                 184.8000030517578,
#                 323.6728820800781,
#                 223.60426330566406,
#                 333.5042419433594
#             ],
#             "ObjectID": 461,
#             "Page": 2,
#             "Path": "//Document/Sect[4]/Sect/Table/TR[5]/TH",
#             "attributes": {
#                 "BBox": [
#                     183.35299999999552,
#                     310.81999999999243,
#                     303.9479999999894,
#                     334.8189999999886
#                 ],
#                 "BlockAlign": "Before",
#                 "ColIndex": 0,
#                 "Height": 24,
#                 "InlineAlign": "Start",
#                 "RowIndex": 4,
#                 "Width": 120.625
#             }
#         },
#         {
#             "Bounds": [
#                 184.8000030517578,
#                 323.6728820800781,
#                 223.60426330566406,
#                 333.5042419433594
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 420,
#             "Page": 2,
#             "Path": "//Document/Sect[4]/Sect/Table/TR[5]/TH/P",
#             "Text": "Public data ",
#             "TextSize": 7.9799957275390625,
#             "attributes": {
#                 "LineHeight": 9.625
#             }
#         },
#         {
#             "Bounds": [
#                 319.32000732421875,
#                 313.13682556152344,
#                 406.6510925292969,
#                 333.2967529296875
#             ],
#             "ObjectID": 462,
#             "Page": 2,
#             "Path": "//Document/Sect[4]/Sect/Table/TR[5]/TD",
#             "attributes": {
#                 "BBox": [
#                     303.9479999999894,
#                     310.81999999999243,
#                     431.50199999999313,
#                     334.8189999999886
#                 ],
#                 "BlockAlign": "Middle",
#                 "ColIndex": 1,
#                 "Height": 24,
#                 "InlineAlign": "Start",
#                 "RowIndex": 4,
#                 "Width": 127.375
#             }
#         },
#         {
#             "Bounds": [
#                 319.32000732421875,
#                 313.13682556152344,
#                 406.6510925292969,
#                 333.2967529296875
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": true,
#             "Lang": "en",
#             "ObjectID": 421,
#             "Page": 2,
#             "Path": "//Document/Sect[4]/Sect/Table/TR[5]/TD/P",
#             "Text": "Information that is openly available ",
#             "TextSize": 7.9799957275390625,
#             "attributes": {
#                 "LineHeight": 10.5
#             }
#         },
#         {
#             "Bounds": [
#                 442.91835021972656,
#                 323.6968231201172,
#                 478.94439697265625,
#                 333.2967529296875
#             ],
#             "ObjectID": 463,
#             "Page": 2,
#             "Path": "//Document/Sect[4]/Sect/Table/TR[5]/TD[2]",
#             "attributes": {
#                 "BBox": [
#                     431.50199999999313,
#                     310.81999999999243,
#                     561.8169999999809,
#                     334.8189999999886
#                 ],
#                 "BlockAlign": "Before",
#                 "ColIndex": 2,
#                 "Height": 24,
#                 "InlineAlign": "Start",
#                 "RowIndex": 4,
#                 "Width": 130.375
#             }
#         },
#         {
#             "Bounds": [
#                 442.91835021972656,
#                 323.6968231201172,
#                 478.94439697265625,
#                 333.2967529296875
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UZWRFE+AdobeClean-SemiCn",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 422,
#             "Page": 2,
#             "Path": "//Document/Sect[4]/Sect/Table/TR[5]/TD[2]/P",
#             "Text": "No impact ",
#             "TextSize": 7.9799957275390625,
#             "attributes": {
#                 "LineHeight": 9.625
#             }
#         },
#         {
#             "Bounds": [
#                 184.5,
#                 275.54087829589844,
#                 309.8320770263672,
#                 289.0682373046875
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "ZWLAXU+AdobeClean-Bold",
#                 "subset": true,
#                 "weight": 700
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 423,
#             "Page": 2,
#             "Path": "//Document/Sect[4]/Sect[2]/H2",
#             "Text": "Adobe Confidential Data ",
#             "TextSize": 10.979995727539062,
#             "attributes": {
#                 "SpaceAfter": 2.875
#             }
#         },
#         {
#             "Bounds": [
#                 184.5,
#                 211.74600219726562,
#                 554.3327789306641,
#                 271.90199279785156
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 424,
#             "Page": 2,
#             "Path": "//Document/Sect[4]/Sect[2]/P",
#             "Text": "Only limited segments of the Adobe workforce need access to data classified as Adobe Confidential in order to perform their jobs. Unauthorized disclosure of Adobe Confidential data would likely cause significant harm (such as financial, contractual, or legal or reputational harm orservice disruptions) to Adobe, its employees, customers, stockholders, and business partners. ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 184.49057006835938,
#                 199.3350067138672,
#                 320.2603759765625,
#                 210.40499877929688
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "Lang": "en",
#             "ObjectID": 425,
#             "Page": 2,
#             "Path": "//Document/Sect[4]/Sect[2]/P[2]",
#             "Text": "Adobe Confidential data includes: ",
#             "TextSize": 9.0,
#             "attributes": {
#                 "SpaceAfter": 4.5
#             }
#         },
#         {
#             "Bounds": [
#                 184.44000244140625,
#                 184.09500122070312,
#                 189.47998046875,
#                 195.1649932861328
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 426,
#             "Page": 2,
#             "Path": "//Document/Sect[4]/Sect[2]/L/LI/Lbl",
#             "Text": "\u2022 ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 191.52000427246094,
#                 184.0919952392578,
#                 444.8892822265625,
#                 195.16200256347656
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 427,
#             "Page": 2,
#             "Path": "//Document/Sect[4]/Sect[2]/L/LI/LBody",
#             "Text": "Data that Adobe is contractually required to treat as confidential ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 184.43699645996094,
#                 165.97500610351562,
#                 189.4769744873047,
#                 177.0449981689453
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 428,
#             "Page": 2,
#             "Path": "//Document/Sect[4]/Sect[2]/L/LI[2]/Lbl",
#             "Text": "\u2022 ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 191.52000427246094,
#                 104.64599609375,
#                 551.7001647949219,
#                 177.04200744628906
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 429,
#             "Page": 2,
#             "Path": "//Document/Sect[4]/Sect[2]/L/LI[2]/LBody",
#             "Text": "Personal information (PI) (unless the personal information meets the definition of Adobe Restricted data) about an individual (including free users, paid users, enterprise users, suppliers, or employees). This can include directly identifiable personal information, such as name, email address, phone number, home address, or precise geolocation information. Personal informationcan also include indirectly identifiable personal information, such as a user GUID, IP address, cookie ID, or device identifier. ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 184.4429931640625,
#                 86.71499633789062,
#                 189.48297119140625,
#                 97.78500366210938
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 430,
#             "Page": 2,
#             "Path": "//Document/Sect[4]/Sect[2]/L/LI[3]/Lbl",
#             "Text": "\u2022 ",
#             "TextSize": 9.0
#         },
#         {
#             "Bounds": [
#                 191.52000427246094,
#                 74.40899658203125,
#                 547.6959838867188,
#                 97.78199768066406
#             ],
#             "Font": {
#                 "alt_family_name": "Clean",
#                 "embedded": true,
#                 "encoding": "WinAnsiEncoding",
#                 "family_name": "Adobe Clean",
#                 "font_type": "Type1",
#                 "italic": false,
#                 "monospaced": false,
#                 "name": "UVJLFE+AdobeClean-Regular",
#                 "subset": true,
#                 "weight": 400
#             },
#             "HasClip": false,
#             "ObjectID": 431,
#             "Page": 2,
#             "Path": "//Document/Sect[4]/Sect[2]/L/LI[3]/LBody",
#             "Text": "Content or data that customers, partners, or users provide to Adobe (unless the content or datameets the definition of Restricted data below) ",
#             "TextSize": 9.0
#         }
#     ],
#     "pages": [
#         {
#             "boxes": {
#                 "CropBox": [
#                     0.0,
#                     0.0,
#                     630.0,
#                     810.0
#                 ],
#                 "MediaBox": [
#                     0.0,
#                     0.0,
#                     630.0,
#                     810.0
#                 ]
#             },
#             "height": 810.0,
#             "is_scanned": false,
#             "page_number": 0,
#             "rotation": 0,
#             "width": 630.0
#         },
#         {
#             "boxes": {
#                 "CropBox": [
#                     0.0,
#                     0.0,
#                     630.0,
#                     810.0
#                 ],
#                 "MediaBox": [
#                     0.0,
#                     0.0,
#                     630.0,
#                     810.0
#                 ]
#             },
#             "height": 810.0,
#             "is_scanned": false,
#             "page_number": 1,
#             "rotation": 0,
#             "width": 630.0
#         },
#         {
#             "boxes": {
#                 "CropBox": [
#                     0.0,
#                     0.0,
#                     630.0,
#                     810.0
#                 ],
#                 "MediaBox": [
#                     0.0,
#                     0.0,
#                     630.0,
#                     810.0
#                 ]
#             },
#             "height": 810.0,
#             "is_scanned": false,
#             "page_number": 2,
#             "rotation": 0,
#             "width": 630.0
#         }
#     ]
# }

# %%
keys_to_remove = ['Bounds', 'Font', "HasClip", "Lang", "ObjectID", "attributes", "Path", "TextSize"]
for element in parsed['elements']:
    for key in keys_to_remove:
        if key in element:
            del element[key]

indices_to_remove = []
for i, element in enumerate(parsed['elements']):
    if 'Text' not in element:
        indices_to_remove.append(i)
        continue
    if element.get('Text') == "\u2022 ":
        indices_to_remove.append(i)
        
for index in reversed(indices_to_remove):
    del parsed['elements'][index]


print(json.dumps(parsed, indent=4))
# Out:
# {
#     "version": {
#         "json_export": "203",
#         "page_segmentation": "5",
#         "schema": "1.1.0",
#         "structure": "1.1099.0",
#         "table_structure": "5"
#     },
#     "extended_metadata": {
#         "ID_instance": "C0 D4 89 F0 A1 BA B2 11 0A 00 67 45 8B 6B C6 23 ",
#         "ID_permanent": "34 46 20 45 46 20 38 35 20 46 30 20 41 31 20 42 41 20 42 32 20 31 31 20 30 41 20 30 30 20 36 37 20 34 35 20 38 42 20 36 42 20 43 36 20 32 33 20 ",
#         "has_acroform": false,
#         "has_embedded_files": false,
#         "is_XFA": false,
#         "is_certified": false,
#         "is_encrypted": false,
#         "is_digitally_signed": false,
#         "language": "EN-US",
#         "page_count": 3,
#         "pdf_version": "1.6",
#         "pdfa_compliance_level": "",
#         "pdfua_compliance_level": ""
#     },
#     "elements": [
#         {
#             "Page": 0,
#             "Text": "Adobe Vendor Security Review Program White Paper "
#         },
#         {
#             "Page": 0,
#             "Text": "Adobe\u00ae Vendor Security Review Program "
#         },
#         {
#             "Page": 0,
#             "Text": "Overview "
#         },
#         {
#             "Page": 0,
#             "Text": "Table of Contents "
#         },
#         {
#             "Page": 0,
#             "Text": "1 "
#         },
#         {
#             "Page": 0,
#             "Text": "Overview "
#         },
#         {
#             "Page": 0,
#             "Text": "1 "
#         },
#         {
#             "Page": 0,
#             "Text": "Adobe Vendor Security "
#         },
#         {
#             "Page": 0,
#             "Text": "Review (VSR) Process "
#         },
#         {
#             "Page": 0,
#             "Text": "1 "
#         },
#         {
#             "Page": 0,
#             "Text": "Data Classification "
#         },
#         {
#             "Page": 0,
#             "Text": "4 "
#         },
#         {
#             "Page": 0,
#             "Text": "VSR Security Controls "
#         },
#         {
#             "Page": 0,
#             "Text": "5 "
#         },
#         {
#             "Page": 0,
#             "Text": "The Adobe Vendor Information Security Standard "
#         },
#         {
#             "Page": 0,
#             "Text": "5 "
#         },
#         {
#             "Page": 0,
#             "Text": "Vendor Engagement "
#         },
#         {
#             "Page": 0,
#             "Text": "6 "
#         },
#         {
#             "Page": 0,
#             "Text": "Privacy Assessment "
#         },
#         {
#             "Page": 0,
#             "Text": "6 "
#         },
#         {
#             "Page": 0,
#             "Text": "Legal Obligations "
#         },
#         {
#             "Page": 0,
#             "Text": "7 "
#         },
#         {
#             "Page": 0,
#             "Text": "Conclusion "
#         },
#         {
#             "Page": 0,
#             "Text": "Managed by the Adobe Information Security team, Adobe\u2019s vendor security review (VSR) program includes a set of requirements to which third-party vendors that collect, store, process, transmit, or dispose of Adobe Internal, Confidential, or Restricted data outside of Adobe-controlled physical offices or data center locations must adhere. Typical scenarios include vendors processing and storing Adobe data at their site, cloud services (e.g., SaaS, PaaS, IaaS, and XaaS), and data centers. "
#         },
#         {
#             "Page": 0,
#             "Text": "The Adobe VSR program evaluates each vendor\u2019s compliance to Adobe\u2019s Vendor Information Security Standard, providing a risk-based review of the vendor\u2019s security practices and enabling Adobe managers to make fact-based decisions concerning whether or not to enter into a relationship with that vendor. "
#         },
#         {
#             "Page": 0,
#             "Text": "The management of vendor relationships and their interactions with Adobe information and technologyresources is an essential element of information security. The VSR program is a logical extension of Adobe\u2019s belief that every action taken on or interaction with data should be conducted with a lens of security to help ensure the security, privacy, and availability of our customers\u2019 and employees\u2019 data, no matter where it is stored or processed, which is one of the key controls within the Adobe Common Controls Framework (CCF). With the VSR program, Adobe helps ensure that its culture of security extends to any vendor with whom the company does business. "
#         },
#         {
#             "Page": 0,
#             "Text": "Adobe Vendor Security Review (VSR) Program Process "
#         },
#         {
#             "Page": 0,
#             "Text": "The VSR program evaluates a third-party vendor\u2019s compliance with the Adobe Vendor Information Security Standard (described above). "
#         },
#         {
#             "Page": 0,
#             "Text": "Business owners within Adobe that wish to enter into a relationship with a third-party vendor initiatethe process with a VSR request, which includes a description of the service provided by the vendor, whether the vendor will process Adobe data off-site, and the classification of the data the vendor intends to process. "
#         },
#         {
#             "Page": 0,
#             "Text": "Based on the information provided by the business owner, Adobe sends the main point of contactat the vendor a detailed questionnaire, including questions from each security control area (see VSR Security Controls section). "
#         },
#         {
#             "Page": 0,
#             "Text": "After the vendor completes and returns the questionnaire, Adobe information security analysts review the information and perform a gap assessment. A vendor is assigned a risk level score of \u201ccritical,\u201d \u201chigh,\u201d \u201cmedium,\u201d or \u201clow\u201d based upon a risk matrix used by our risk analysts. If Adobe finds any gaps in, or deviations from, Adobe security standards, a risk analyst holds discussions with the business owner to understand the details about the gap and to provide potential remediation suggestions. The analyst documents the recommended remediation and the actions to be performed by the vendor and/or the business owner. If necessary, risk analysts will meet directly with vendors to resolve more complex issues. "
#         },
#         {
#             "Page": 0,
#             "Text": "Data Classification "
#         },
#         {
#             "Page": 0,
#             "Text": "Adobe developed the Adobe Data Classification and Handling Standard to aid in ensuring the security and privacy of all data that Adobe collects, processes, stores, uses, or otherwise handles regardless of whether the data is owned by Adobe or a third party, where the data is located (e.g., Adobe data center,colocation), or the type of hardware or media on which the data resides, whether paper or electronic (e.g., server, desktop, laptop, mobile device, USB flash drive). The standard establishes that all data "
#         },
#         {
#             "Page": 1,
#             "Text": "collected, processed, transmitted, stored, or destroyed by or on behalf of Adobe must be classified and then protected in accordance with its designated classification. The specific classifications in the standard define with whom employees can share Adobe data and determine where and how toshare, protect, and secure this data. "
#         },
#         {
#             "Page": 1,
#             "Text": "The Adobe Data Classification and Handling Standard includes four (4) classifications: "
#         },
#         {
#             "Page": 1,
#             "Text": "Adobe Restricted "
#         },
#         {
#             "Page": 1,
#             "Text": "Adobe Confidential "
#         },
#         {
#             "Page": 1,
#             "Text": "Adobe Internal "
#         },
#         {
#             "Page": 1,
#             "Text": "Public "
#         },
#         {
#             "Page": 1,
#             "Text": "A VSR is required for all third-party vendors that store or process data classified as Adobe Restricted, Confidential, or Internal off-premise (not at Adobe). Depending on the classification of the data handled by the vendor, a new VSR is required either annually or biannually (see Recertification section). "
#         },
#         {
#             "Page": 1,
#             "Text": "Each data classification includes specific protection and handling requirements, and if data falls into multiple classifications, it must be protected in accordance with the most restrictive classification. "
#         },
#         {
#             "Page": 1,
#             "Text": "Any business owner requesting an exception to the Data Classification and Handling Standard mustsubmit a request in writing to the appropriate management personnel for review and approval. "
#         },
#         {
#             "Page": 1,
#             "Text": "If Adobe finds that data that should be classified as Adobe Restricted or Adobe Confidential has been handled incorrectly, either due to incorrect classification or negligence in its handling, Adobe may take disciplinary action against the offender. "
#         },
#         {
#             "Page": 1,
#             "Text": "Adobe Restricted Data "
#         },
#         {
#             "Page": 1,
#             "Text": "Adobe Restricted data is the most restrictive classification and requires the most care; only very limited segments of the Adobe workforce need access to Adobe Restricted data to perform their jobs. Unauthorized disclosure of Adobe Restricted data could cause severe harm to Adobe, its employees, customers, stockholders, or business partners. Adobe Restricted data includes the following: "
#         },
#         {
#             "Page": 1,
#             "Text": "Cardholder data, as defined by the PCI DSS "
#         },
#         {
#             "Page": 1,
#             "Text": "Bank account numbers "
#         },
#         {
#             "Page": 1,
#             "Text": "Social Security and taxpayer identification numbers relating to an individual "
#         },
#         {
#             "Page": 1,
#             "Text": "Driver\u2019s license numbers or identification card number used to verify an individual\u2019s identity(state, military, student, voter, tribal, operator\u2019s number, etc.) "
#         },
#         {
#             "Page": 1,
#             "Text": "Passport information "
#         },
#         {
#             "Page": 1,
#             "Text": "Credential stores used to authenticate Adobe users or employees, such as Active Directory (butnot including personal password managers, such as Splash ID) "
#         },
#         {
#             "Page": 1,
#             "Text": "Credentials, secrets, tokens, or keys permitting access to systems storing Restricted data or permitting decryption of Restricted data (e.g., identity management systems, deployment systems, or secret stores) "
#         },
#         {
#             "Page": 1,
#             "Text": "Digital certificates used for signing Adobe software "
#         },
#         {
#             "Page": 1,
#             "Text": "Medical or health information, including electronically protected health information (ePHI) "
#         },
#         {
#             "Page": 1,
#             "Text": "Federal classified or intelligence contracts "
#         },
#         {
#             "Page": 1,
#             "Text": "Security question response (including mother\u2019s maiden name) or Personal IdentificationNumber (PIN) "
#         },
#         {
#             "Page": 1,
#             "Text": "Private key digital signatures "
#         },
#         {
#             "Page": 1,
#             "Text": "Biometric information "
#         },
#         {
#             "Page": 2,
#             "Text": "Genetic information "
#         },
#         {
#             "Page": 2,
#             "Text": "Racial origin "
#         },
#         {
#             "Page": 2,
#             "Text": "Ethnic origin "
#         },
#         {
#             "Page": 2,
#             "Text": "Political opinions "
#         },
#         {
#             "Page": 2,
#             "Text": "Religious beliefs "
#         },
#         {
#             "Page": 2,
#             "Text": "Philosophical beliefs "
#         },
#         {
#             "Page": 2,
#             "Text": "Trade union membership "
#         },
#         {
#             "Page": 2,
#             "Text": "Sex life information "
#         },
#         {
#             "Page": 2,
#             "Text": "Sexual orientation "
#         },
#         {
#             "Page": 2,
#             "Text": "Criminal offenses and convictions "
#         },
#         {
#             "Page": 2,
#             "Text": "Birth certificate "
#         },
#         {
#             "Page": 2,
#             "Text": "Marriage certificate "
#         },
#         {
#             "Page": 2,
#             "Text": "Information or data collected through use or operation of an automated license platerecognition system "
#         },
#         {
#             "Page": 2,
#             "Text": "Classification "
#         },
#         {
#             "Page": 2,
#             "Text": "Examples "
#         },
#         {
#             "Page": 2,
#             "Text": "Impact of Unauthorized Disclosure "
#         },
#         {
#             "Page": 2,
#             "Text": "Restricted data has a High Business Impact "
#         },
#         {
#             "Page": 2,
#             "Text": "Regulatory protected data, material financial data, intellectual property, passwords and credential. "
#         },
#         {
#             "Page": 2,
#             "Text": "Likely to cause severe harm to Adobe, its employees, customers, stockholders, or business partners. "
#         },
#         {
#             "Page": 2,
#             "Text": "Confidential data has a Medium Business Impact "
#         },
#         {
#             "Page": 2,
#             "Text": "People related data (salary, benefits), data with need-to- know restrictions like source code, Customer Files, product roadmaps, Adobe financial information. "
#         },
#         {
#             "Page": 2,
#             "Text": "Likely to cause significant harm to Adobe, its employees, customers, stockholders, or business partners "
#         },
#         {
#             "Page": 2,
#             "Text": "Internal data has a Moderate "
#         },
#         {
#             "Page": 2,
#             "Text": "Business Impact "
#         },
#         {
#             "Page": 2,
#             "Text": "Note: The default type for unclassified data is Internal "
#         },
#         {
#             "Page": 2,
#             "Text": "Operational planning, collaboration and internal communications, IT Knowledge Center articles. "
#         },
#         {
#             "Page": 2,
#             "Text": "May cause minor embarrassment or operational inconvenience "
#         },
#         {
#             "Page": 2,
#             "Text": "Public data "
#         },
#         {
#             "Page": 2,
#             "Text": "Information that is openly available "
#         },
#         {
#             "Page": 2,
#             "Text": "No impact "
#         },
#         {
#             "Page": 2,
#             "Text": "Adobe Confidential Data "
#         },
#         {
#             "Page": 2,
#             "Text": "Only limited segments of the Adobe workforce need access to data classified as Adobe Confidential in order to perform their jobs. Unauthorized disclosure of Adobe Confidential data would likely cause significant harm (such as financial, contractual, or legal or reputational harm orservice disruptions) to Adobe, its employees, customers, stockholders, and business partners. "
#         },
#         {
#             "Page": 2,
#             "Text": "Adobe Confidential data includes: "
#         },
#         {
#             "Page": 2,
#             "Text": "Data that Adobe is contractually required to treat as confidential "
#         },
#         {
#             "Page": 2,
#             "Text": "Personal information (PI) (unless the personal information meets the definition of Adobe Restricted data) about an individual (including free users, paid users, enterprise users, suppliers, or employees). This can include directly identifiable personal information, such as name, email address, phone number, home address, or precise geolocation information. Personal informationcan also include indirectly identifiable personal information, such as a user GUID, IP address, cookie ID, or device identifier. "
#         },
#         {
#             "Page": 2,
#             "Text": "Content or data that customers, partners, or users provide to Adobe (unless the content or datameets the definition of Restricted data below) "
#         }
#     ],
#     "pages": [
#         {
#             "boxes": {
#                 "CropBox": [
#                     0.0,
#                     0.0,
#                     630.0,
#                     810.0
#                 ],
#                 "MediaBox": [
#                     0.0,
#                     0.0,
#                     630.0,
#                     810.0
#                 ]
#             },
#             "height": 810.0,
#             "is_scanned": false,
#             "page_number": 0,
#             "rotation": 0,
#             "width": 630.0
#         },
#         {
#             "boxes": {
#                 "CropBox": [
#                     0.0,
#                     0.0,
#                     630.0,
#                     810.0
#                 ],
#                 "MediaBox": [
#                     0.0,
#                     0.0,
#                     630.0,
#                     810.0
#                 ]
#             },
#             "height": 810.0,
#             "is_scanned": false,
#             "page_number": 1,
#             "rotation": 0,
#             "width": 630.0
#         },
#         {
#             "boxes": {
#                 "CropBox": [
#                     0.0,
#                     0.0,
#                     630.0,
#                     810.0
#                 ],
#                 "MediaBox": [
#                     0.0,
#                     0.0,
#                     630.0,
#                     810.0
#                 ]
#             },
#             "height": 810.0,
#             "is_scanned": false,
#             "page_number": 2,
#             "rotation": 0,
#             "width": 630.0
#         }
#     ]
# }
